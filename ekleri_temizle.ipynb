# %%
ekler = {
  "laştırılmak",
  "leştiremediklerinden",
  "laştırılma",
  "laştırılmak",
  "laştırmak",
  "leştirilebilme",
  "laştırılabilme",
  "laştırma",
  "lendirebilmek",
  "sızlaştırmak",
  "çılar",
  "sizleştirebilme",
  "lendirilebilme",
  "leştirilme",
  "laştırabilme",
  "çilik",
  "mezlik",
  "lenebilen",
  "leştirme",
  "leştirmek",
  "laşma",
  "laşmak",
  "cılık",
  "ıcılık",
  "cilik",
  "icilik",
  "lendirmek",
  "lendirme",
  "laştırılabilmek",
  "lendirilebilmek",
  "landırılma",
  "landırılmak",
  "landırmak",
  "landırma",
  "lendirebilmek",
  "lik",
  "lık",
  "luk",
  "lük",
  "cık",
  "cik",
  "cuk",
  "cük",
  "cı",
  "ci",
  "cu",
  "cü",
  "çı",
  "çi",
  "çu",
  "çü",
  "dan",
  "den",
  "sızlaşmasına",
  "leştirebilme",
  "ıveriyordu",
  "veriyordu",
  "lanabilirlik",
  "laşmış",
  "leştirilmeye",
  "liği",
  "lığı",
  "lık",
  "lük",
  "lık",
  "lük",
  "laştırabilme",
  "lendirebilme",
  "lendirebilmek",
  "landırabilme",
  "landırabilmek",
  "sizleşebilme",
  "sizleşebilmek",
  "sızlaşabilme",
  "sızlaşabilmek",
  "leştiricilik",
  "landırılabilme",
  "landırılabilmek",
  "leşebilme",
  "leşebilmek",
  "ndaki",
  "leştirirler",
  "leştirilmek",
  "lar",
  "ler",
  "leri",
  "ları",
  "lerinin",
  "larının",
  "ılagelmiştir",
  "lettirilmek",
  "ülebilirlik",
  "ulabilirlik",
  "lendirilişinde",
  "cularımız",
  "cılarımız",
  "mazlık",
  "sizliğin",
  "sızlığın",
  "leyebilme",
  "letebilme",
  "letilebilme",
  "leştiriliş",
  "eştirildi",
  "abildiğine",
  "sinde",
  "sizcesine",
  "leyebilmek",
  "lettirilme",
  "letebilmek",
  "götürmez",
  "lendirilme",
  "leştirici",
  "lendirilmek",
  "ıvermişti",
  "leştirilemeyen",
  "lenmek",
  "leyebilmek",
  "lerin",
  "lilerin",
  "giller",
  "gillerden",
  "gillerde",
  "ilebilme",
  "ılabilme",
  "laşabilme",
  "laşabilmek",
  "leşebilme",
  "leşebilmek",
  "ilebilmek",
  "abilme",
  "lıların",
  "ini",
  "siz",
  "sız",
  "suz",
  "süz",
  "çı",
  "çi",
  "çu",
  "çü",
  "ıveriyordu",
  "selleştirmek",
  "tirmişlerdir",
  "mamazlık",
  "tur",
  "dır",
  "dir",
  "dur",
  "dür",
  "dı",
  "di",
  "du",
  "dü",
  "daki",
  "deki",
  "ki",
  "sizliğimden",
  "sizliğinden",
  "sizliğine",
  "latılabilmek",
  "tirilebilmek",
  "macalarıyla",
  "larımızın",
  "leştirebilmek",
  "ilebilmek",
  "nebilirlik",
  "yebilmek",
  "tebilmek",
  "ebilmek",
  "lenebilmek",
  "abilmek",
  "tabilmek",
  "yabilmek",
  "cilerin",
  "nilebilmek",
  "casını",
  "lı",
  "li",
  "lu",
  "lü",
  "ılıvermek",
  "lere",
  "lara",
  "layıcılık",
  "letilmek",
  "lettirme",
  "si",
  "uluveriyor",
  "tırıvermek",
  "nda",
  "lendiril",
  "leşmenin",
  "turuvermek",
  "turuvermiş",
  "leştirilen",
  "tırabilme",
  "tılabilme",
  "ebilme",
  "ülebilme",
  "ılabilme",
  "sızlıkla",
  "lendirici",
  "leşme",
  "leşmek",
  "lenme",
  "iyle",
  "sızlık",
  "sız",
  "sizlik",
  "siz",
  "cinin",
  "leşmesini",
  "nların",
  "sindeki",
  "nilmeyen",
  "letmek",
  "nun",
  "nın",
  "nin",
  "sever",
  "siz",
  "larda",
  "lerde",
  "lerden",
  "lardan",
  "sel",
  "iniz",
  "ınız",
  "tıldığında",
  "kedebilmek",
  "edebilmek",
  "etmek",
  "ketmek",
  "letme",
  "letmek",
  "leyicilik",
  "lılığın",
  "lılarla",
  "tırıver",
  "tırılış",
  "le",
  "la",
  "ılarak",
  "ılabilme",
  "lılaşmasını",
  "selleştirme",
  "leştiriyor",
  "leşiyorken",
  "layabilme",
  "ebilirliği",
  "lik",
  "leştirildi",
  "abildiğine",
  "ten",
  "dıklarında",
  "ünde",
  "yebilmek",
  "lamasını",
  "larınızın",
  "dıklarında",
  "leştir",
  "sızcasına",
  "ların",
  "ınki",
  "leştirilmek",
  "mazcasına",
  "ılıveriyor",
  "larıdır",
  "tan",
  "lenebilme",
  "latabilme",
  "dirilebilme",
  "tilebilme",
  "lanabilme",
  "ılabilirlik",
  "lığın",
  "leş",
  "lardan",
  "suzcasına",
  "luyum",
  "latmak",
  "lanmak",
  "larına",
  "lerinde",
  "ilivermesi",
  "cünün",
  "izm",
  "sallaşması",
  "iliş",
  "laştırmak",
  "ist",
  "landırılış",
  "tabilme",
  "lendirim",
  "lılara",
  "ilmiştir",
  "lanma",
  "laştır",
  "sizleş",
  "laştırıcı",
  "sızlaşma",
  "lattırma",
  "leyici",
  "memecesine",
  "emeyişinin",
  "laşma",
  "lığın",
  "lendir",
  "diriş",
  "mişlik",
  "sıyla",
  "lamak",
  "layış",
  "lemek",
  "layış",
  "layış",
  "layış",
  "laş",
  "sun",
  "yebilmek",
  "ılabilme",
  "ülebilme",
  "ulabilme",
  "ilebilme",
  "ılabilmek",
  "ülebilmek",
  "ulabilmek",
  "ilebilmek",
  "lettirmek",
  "tırıverirdi",
  "oğlu",
  "diricilik",
  "sinin",
  "ndırılarak",
  "dırılarak",
  "suzlaştır",
  "sızlaştır",
  "lanmada",
  "letilme",
  "ebilme",
  "ebilmek",
  "lamasına",
  "dayabilme",
  "lendiriliş",
  "icilik",
  "ıcılık",
  "leyiş",
  "leniş",
  "cağız",
}

# sort ekler by length and alphabetically
ekler_sorted = sorted(ekler, key=lambda x: (len(x), x), reverse=True)

len(ekler_sorted)
# Out:
# 306

# %%
after_itu_kokler = dict()
with open("./after_itu_kokler_filtered.txt", "r", encoding="utf-8") as f:
    for line in f:
        after_itu_kokler[line.strip()] = True

len(after_itu_kokler)
# Out:
# 37287

# %%
for ek in ekler_sorted:
  for kok, keep in after_itu_kokler.items():
    eksiz_kok = kok[:-len(ek)]
    if len(eksiz_kok) < 2:
      continue
    if kok.endswith(ek) and eksiz_kok in after_itu_kokler and keep:
      after_itu_kokler[kok] = False

# print true and false kokler count
print(sum(after_itu_kokler.values()))

kokler = list(after_itu_kokler.keys())
kokler.sort(key=lambda x: x)

with open("./after_itu_kokler_filtered.txt", "w", encoding="utf-8") as f:
  for kok in kokler:
    if after_itu_kokler[kok]:
      f.write(f"{kok}\n")
# Out:
# 37287
